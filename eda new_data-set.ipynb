# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Main Db-
df = pd.read_csv(r"C:\Users\anktr\Documents\FINAL YEAR PROJECT\Data-Set\final_data.csv")
df
# Out:
#                               State                  District      Crop  \
# 0       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 1       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 2       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 3       Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut
# 4       Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut
# ...                             ...                       ...       ...
# 665679                  West Bengal           PURBA BARDHAMAN     Wheat
# 665680                  West Bengal                   PURULIA     Wheat
# 665681                  West Bengal                   PURULIA     Wheat
# 665682                  West Bengal                   PURULIA     Wheat
# 665683                  West Bengal                   PURULIA     Wheat
#
#            Year      Season    Area Area Units     Yield  New Production
# ...

# %%
df = df.sort_values(by=['Year'])
df.reset_index(inplace=True)
df = df.drop(['index'],axis=1)

# %%
df
# Out:
#                  State               District               Crop     Year  \
# 0                Bihar                 SUPAUL              Maize  1997-98
# 1                Bihar                SHEOHAR  Rapeseed &Mustard  1997-98
# 2                Bihar             SHEIKHPURA  Rapeseed &Mustard  1997-98
# 3                Bihar              SITAMARHI              Wheat  1997-98
# 4        Uttar Pradesh      SANT KABEER NAGAR               Gram  1997-98
# ...                ...                    ...                ...      ...
# 665679       Meghalaya                RI BHOI             Ginger  2019-20
# 665680       Meghalaya       SOUTH GARO HILLS             Ginger  2019-20
# 665681       Meghalaya  SOUTH WEST GARO HILLS             Ginger  2019-20
# 665682  Madhya Pradesh              ALIRAJPUR       Sweet potato  2019-20
# 665683  Madhya Pradesh               SHIVPURI               Rice  2019-20
#
#             Season     Area Area Units      Yield  New Production
# ...

# %% [markdown]
# ## New Variables
# ##### Looking at the seven variables, we could extract more information if new variable could be created using present variables. Some of the possibilities are: Different caterories (Cereal, Pulses,Fruits,Beans,Vegetables, Spices, fibres, Nuts, Natural Polymer,Coffee, Tea, Total foodgrain, Pulses, Oilseeds, Paddy, Commercial, Sugarcane, forage plants and Others)

# %%
crop=df['Crop']
def cat_crop(crop):
    for i in ['Rice','Maize','Wheat','Barley','Varagu','Other Cereals & Millets','Ragi','Small millets','Bajra','Jowar', 'Paddy','Total foodgrain','Jobster']:
        if crop==i:
            return 'Cereal'
    for i in ['Moong','Urad','Arhar/Tur','Peas & beans','Masoor',
              'Other Kharif pulses','other misc. pulses','Ricebean (nagadal)',
              'Rajmash Kholar','Lentil','Samai','Blackgram','Korra','Cowpea(Lobia)',
              'Other  Rabi pulses','Other Kharif pulses','Peas & beans (Pulses)','Pulses total','Gram']:
        if crop==i:
            return 'Pulses'
    for i in ['Peach','Apple','Litchi','Pear','Plums','Ber','Sapota','Lemon','Pome Granet',
               'Other Citrus Fruit','Water Melon','Jack Fruit','Grapes','Pineapple','Orange',
               'Pome Fruit','Citrus Fruit','Other Fresh Fruits','Mango','Papaya','Coconut','Banana']:
        if crop==i:
            return 'Fruits'
    for i in ['Bean','Lab-Lab','Moth','Guar seed','Soyabean','Horse-gram']:
        if crop==i:
            return 'Beans'
    for i in ['Turnip','Peas','Beet Root','Carrot','Yam','Ribed Guard','Ash Gourd ','Pump Kin','Redish','Snak Guard','Bottle Gourd',
              'Bitter Gourd','Cucumber','Drum Stick','Cauliflower','Beans & Mutter(Vegetable)','Cabbage',
              'Bhindi','Tomato','Brinjal','Khesari','Sweet potato','Potato','Onion','Tapioca','Colocosia']:
              if crop==i:
                return 'Vegetables'
    for i in ['Perilla','Ginger','Cardamom','Black pepper','Dry ginger','Garlic','Coriander','Turmeric','Dry chillies','Cond-spcs other']:
        if crop==i:
            return 'spices'
    for i in ['other fibres','Kapas','Jute & mesta','Jute','Mesta','Cotton(lint)','Sannhamp']:
        if crop==i:
            return 'fibres'
    for i in ['Arcanut (Processed)','Atcanut (Raw)','Cashewnut Processed','Cashewnut Raw','Cashewnut','Arecanut','Groundnut']:
        if crop==i:
            return 'Nuts'
    for i in ['other oilseeds','Safflower','Niger seed','Castor seed','Linseed','Sunflower','Rapeseed &Mustard','Sesamum','Oilseeds total']:
        if crop==i:
            return 'oilseeds'
    for i in ['Tobacco','Coffee','Tea','Sugarcane','Rubber']:
        if crop==i:
            return 'Commercial'

df['cat_crop']=df['Crop'].apply(cat_crop)

# %%
data_up = df[df['State']=='Uttar Pradesh']

# %%
# Data-Frame for Uttar-Pradesh
data_up
# Out:
#                 State            District          Crop     Year  Season  \
# 4       Uttar Pradesh   SANT KABEER NAGAR          Gram  1997-98    Rabi
# 10      Uttar Pradesh  SANT RAVIDAS NAGAR          Gram  1997-98    Rabi
# 16      Uttar Pradesh        SHAHJAHANPUR          Gram  1997-98    Rabi
# 19      Uttar Pradesh          SAHARANPUR          Gram  1997-98    Rabi
# 30      Uttar Pradesh          RAE BARELI          Gram  1997-98    Rabi
# ...               ...                 ...           ...      ...     ...
# 641219  Uttar Pradesh          SAHARANPUR  Dry chillies  2018-19  Kharif
# 641228  Uttar Pradesh             SAMBHAL  Dry chillies  2018-19  Kharif
# 641237  Uttar Pradesh            PILIBHIT  Dry chillies  2018-19  Kharif
# 641248  Uttar Pradesh          PRATAPGARH  Dry chillies  2018-19  Kharif
# 641256  Uttar Pradesh          RAE BARELI  Dry chillies  2018-19  Kharif
#
#           Area Area Units     Yield  New Production cat_crop
# ...

# %%
#data_up.reset_index(inplace=True)

# %%
data_up.columns

# %%
#data_up

# %%
#data_up = data_up.drop(['index'],axis=1)

# %%
#data_up

# %% [markdown]
# ## Data Visualization

# %%
data_up.groupby('Season')['Area'].mean().plot.bar()
plt.title("Average Area required in Different Seasons")
# Out:
# Text(0.5, 1.0, 'Average Area required in Different Seasons')

# %%
sns.set_style('whitegrid')
sns.set(rc = {'figure.figsize':(20,8)})
plt.xticks(rotation=90)
sns.countplot(x='State',data=df,hue='cat_crop')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
data_up.groupby('Crop')['Yield'].mean().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Yield',fontsize='15')
plt.title('Average Yield of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Yield of Different Crops in Uttar Pradesh')

# %%
data_up.groupby('Year')['New Production'].mean().plot.line()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Avg Production',fontsize='15')
plt.title('Average Production of Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Production of Uttar Pradesh')

# %%
data_up.groupby('Crop')['New Production'].mean().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Avg Production',fontsize='15')
plt.title('Average Production of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Production of Different Crops in Uttar Pradesh')

# %%
data_up.groupby('Year')['Yield'].mean().plot.line()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Avg Yield',fontsize='15')
plt.title('Average Yield of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Yield of Different Crops in Uttar Pradesh')

# %%
#g=sns.relplot(x=data_up['District'],y=data_up['Area'],hue='Season',data= data_up,kind='line')
#g.fig.set_figwidth(40,6)
#plt.xticks(rotation=90)
#plt.show()'''

# %%
#data_up

# %%
#plt.subplot(1, 2, 1)
#plt.plot(data_up['New Production'])
#plt.subplot(1, 2, 2)
#plt.plot(data_up['Yield'])

# %%
#plt.plot(data_up['Yield'])

# %%
#x=df.groupby('Crop')['New Production'].mean()
#x

# %%
#x2 = data_up.groupby('Crop')['New Production'].mean()
#df2 = x2.to_frame()

# %%
#df2 = df2['New Production'].round(3)

# %%
#df2.plot(kind='bar')

# %%
sns.barplot(x='Year',y='New Production',data=data_up,lw=None,palette='flare')
plt.xticks(rotation=90)
plt.show()

# %%
#t = data_up.sort_values(by=['Year'])

# %%
#t

# %%
df

# %%
print(df['New Production'].mean())
df.groupby('Crop')['New Production'].sum().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Avg Production',fontsize='15')
plt.title('Average Production of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# 61894.92162726446
# Text(0.5, 1.0, 'Average Production of Different Crops in Uttar Pradesh')

# %%
#print(df['New Production'].mean())
df.groupby('Crop')['New Production'].mean().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Avg Production',fontsize='15')
plt.title('Average Production of Different Crops in India',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Production of Different Crops in India')

# %%
df.groupby('Year')['New Production'].mean().plot.line()
plt.xlabel('Year',fontsize='15')
plt.ylabel('Avg Production',fontsize='15')
plt.title('Average Production of Crops in India',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Average Production of Crops in India')

# %%
#sns.barplot(x='State',y='New Production',data=df,hue='cat_crop',lw=None,palette='flare')
#plt.xticks(rotation=90)
#plt.show()

# %%
data_up.groupby('Crop')['Yield'].sum().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Yeild',fontsize='15')
plt.legend()
plt.title('Total Yeild of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Total Yeild of Different Crops in Uttar Pradesh')

# %%
data_up.groupby('Crop')['New Production'].sum().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Production',fontsize='15')
plt.legend()
plt.title('Total Production of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Total Production of Different Crops in Uttar Pradesh')

# %%
data_up.groupby('Crop')['Area'].sum().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Area',fontsize='15')
plt.legend()
plt.title('Total Area of Different Crops in Uttar Pradesh',fontsize='20')
# Out:
# Text(0.5, 1.0, 'Total Area of Different Crops in Uttar Pradesh')

# %%
#data_up.groupby('Crop')['New Production'].mean().plot.bar()
#plt.xlabel('Crop',fontsize='15')
#plt.ylabel('Production',fontsize='15')
#plt.title('Avg. Production of Different Crops in Uttar Pradesh',fontsize='20')

# %%
df.groupby('Crop')['Area'].mean().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Area',fontsize='15')
plt.title('Avg. Area of Different Crops in India',fontsize='20')
plt.figure(figsize=(10,10))
plt.show()

# %%
df.groupby('Crop')['New Production'].sum().plot.bar()
plt.xlabel('Crop',fontsize='15')
plt.ylabel('Production',fontsize='15')
plt.title('Total Production of Different Crops in India',fontsize='20')
plt.figure(figsize=(10,10))
plt.show()

# %%
sns.barplot(x='State',y='New Production',data=df,palette='rocket')
plt.xticks(rotation=90)
plt.title("Production by Different States")
plt.show()

# %% [markdown]
# # Reading the data for year wise rainfall in different states

# %%
rainfall =  pd.read_csv(r"C:\Users\anktr\Documents\FINAL YEAR PROJECT\Data-Set\rainfall_cleaned.csv",delimiter=',')
rainfall
# Out:
#                         STATES  YEAR    JAN    FEB     MAR     APR    MAY  \
# 0    ANDAMAN & NICOBAR ISLANDS  2000  53.00  59.00  171.30  218.10  422.8
# 1    ANDAMAN & NICOBAR ISLANDS  2001  89.00  15.70  143.30   30.10  705.3
# 2    ANDAMAN & NICOBAR ISLANDS  2002  10.60   0.00   11.50  100.20  366.7
# 3    ANDAMAN & NICOBAR ISLANDS  2003  44.30   7.90  149.20   19.40  296.3
# 4    ANDAMAN & NICOBAR ISLANDS  2004  54.50  35.90   36.50   41.60  505.1
# ..                         ...   ...    ...    ...     ...     ...    ...
# 411                WEST BENGAL  2011   5.50  11.30   55.85  105.00  190.2
# 412                WEST BENGAL  2012  28.00  14.60   24.95  108.75  123.3
# 413                WEST BENGAL  2013   2.75  16.80   18.45   80.15  246.2
# 414                WEST BENGAL  2014   0.55  34.40   28.80   24.90  216.5
# 415                WEST BENGAL  2015  14.30  10.25   42.05  118.85  181.1
#
#         JUN     JUL     AUG     SEP     OCT     NOV     DEC   ANNUAL
# ...

# %%
rainfall1=rainfall.copy()
rainfall1 = rainfall1.groupby(['STATES','YEAR'],as_index=True).mean()

# %%
mat6 = np.matrix(rainfall1.iloc[:,12].unstack(level=-1).reset_index().values[:,1:],dtype='float').T
fig = plt.figure(num=6,figsize=(18,8))
ax = fig.add_subplot(1,1,1)
ax.set_yticks(np.arange(len(rainfall1.iloc[:,12].unstack(level=-1).reset_index().columns[1:])))
ax.set_xticks(np.arange(len(rainfall1.iloc[:,12].unstack(level=-1).reset_index().values[:,0])))
ax.set_yticklabels(rainfall1.iloc[:,12].unstack(level=-1).reset_index().columns[1:])
ax.set_xticklabels(rainfall1.iloc[:,12].unstack(level=-1).reset_index().values[:,0],rotation='vertical')
plt.imshow(mat6, cmap='Blues')
plt.colorbar()
plt.title('Annual Rainfall in mm/sqmt')
plt.show()
# Out:
# C:\Users\anktr\AppData\Local\Temp/ipykernel_11088/2706296440.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
# %whos
